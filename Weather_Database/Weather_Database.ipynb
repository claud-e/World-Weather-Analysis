# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url=f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={weather_api_key}"

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    url=f"http://api.openweathermap.org/data/2.5/weather?q={city.title()}&appid={weather_api_key}"
    city_url = url

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description= city_weather["weather"][0]["description"]
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather description": weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | kaitangata
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | dalby
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | boguchany
# Processing Record 7 of Set 1 | sri aman
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | aksarka
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | umm kaddadah
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | dolinsk
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | broken hill
# Processing Record 19 of Set 1 | ranong
# Processing Record 20 of Set 1 | saint-raymond
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | padang
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | ambon
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | clifton
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | lac du bonnet
# Processing Record 36 of Set 1 | yerbogachen
# Processing Record 37 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 1 | moskovskiy
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | richards bay
# Processing Record 42 of Set 1 | alofi
# Processing Record 43 of Set 1 | tukrah
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | xining
# Processing Record 47 of Set 1 | adrar
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | port macquarie
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | chiungutwa
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | jiangyou
# Processing Record 6 of Set 2 | abu kamal
# Processing Record 7 of Set 2 | sola
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | mitchell
# Processing Record 10 of Set 2 | pevek
# Processing Record 11 of Set 2 | beloha
# Processing Record 12 of Set 2 | homer
# Processing Record 13 of Set 2 | bandarbeyla
# Processing Record 14 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | pisco
# Processing Record 20 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | pinsk
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | naze
# Processing Record 25 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | iracoubo
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | beringovskiy
# Processing Record 31 of Set 2 | eyl
# Processing Record 32 of Set 2 | ulladulla
# Processing Record 33 of Set 2 | sakakah
# Processing Record 34 of Set 2 | banda aceh
# Processing Record 35 of Set 2 | mier
# Processing Record 36 of Set 2 | san cristobal
# Processing Record 37 of Set 2 | deputatskiy
# Processing Record 38 of Set 2 | marsh harbour
# Processing Record 39 of Set 2 | ambilobe
# Processing Record 40 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | karpogory
# Processing Record 43 of Set 2 | cururupu
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | shrigonda
# Processing Record 46 of Set 2 | la grande
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | korla
# Processing Record 50 of Set 2 | skogn
# Processing Record 1 of Set 3 | ilulissat
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | monywa
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | broome
# Processing Record 8 of Set 3 | manono
# Processing Record 9 of Set 3 | maxixe
# Processing Record 10 of Set 3 | buguruslan
# Processing Record 11 of Set 3 | talnakh
# Processing Record 12 of Set 3 | opuwo
# Processing Record 13 of Set 3 | sept-iles
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | roald
# Processing Record 16 of Set 3 | calama
# Processing Record 17 of Set 3 | gastonia
# Processing Record 18 of Set 3 | diffa
# Processing Record 19 of Set 3 | san ramon
# Processing Record 20 of Set 3 | cockburn town
# Processing Record 21 of Set 3 | kendal
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | ziro
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | reconquista
# Processing Record 26 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 3 | ondjiva
# Processing Record 29 of Set 3 | neiafu
# Processing Record 30 of Set 3 | sibolga
# Processing Record 31 of Set 3 | kapaa
# Processing Record 32 of Set 3 | cape town
# Processing Record 33 of Set 3 | shikhazany
# Processing Record 34 of Set 3 | binzhou
# Processing Record 35 of Set 3 | mahajanga
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | los llanos de aridane
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | kemin
# Processing Record 42 of Set 3 | poum
# Processing Record 43 of Set 3 | mercedes
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | kyritz
# Processing Record 46 of Set 3 | leningradskiy
# Processing Record 47 of Set 3 | saint-philippe
# Processing Record 48 of Set 3 | aksu
# Processing Record 49 of Set 3 | iranshahr
# Processing Record 50 of Set 3 | westport
# Processing Record 1 of Set 4 | bara
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | riva
# Processing Record 4 of Set 4 | sao filipe
# Processing Record 5 of Set 4 | calamar
# Processing Record 6 of Set 4 | ylojarvi
# Processing Record 7 of Set 4 | vila
# Processing Record 8 of Set 4 | skerries
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | sabang
# Processing Record 11 of Set 4 | locri
# Processing Record 12 of Set 4 | edd
# Processing Record 13 of Set 4 | palmer
# Processing Record 14 of Set 4 | taoudenni
# Processing Record 15 of Set 4 | rocha
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | los alamos
# Processing Record 18 of Set 4 | kamenka
# Processing Record 19 of Set 4 | camacha
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | asfi
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | marawi
# Processing Record 24 of Set 4 | fairbanks
# Processing Record 25 of Set 4 | pacific grove
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | kirovskiy
# Processing Record 28 of Set 4 | mastung
# Processing Record 29 of Set 4 | ayan
# Processing Record 30 of Set 4 | san pedro del pinatar
# Processing Record 31 of Set 4 | norman wells
# Processing Record 32 of Set 4 | ceska kamenice
# Processing Record 33 of Set 4 | poso
# Processing Record 34 of Set 4 | cayenne
# Processing Record 35 of Set 4 | waingapu
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | hualmay
# Processing Record 39 of Set 4 | lianzhou
# Processing Record 40 of Set 4 | russell
# Processing Record 41 of Set 4 | zapolyarnyy
# Processing Record 42 of Set 4 | harper
# Processing Record 43 of Set 4 | namatanai
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | matara
# Processing Record 47 of Set 4 | haverfordwest
# Processing Record 48 of Set 4 | constitucion
# Processing Record 49 of Set 4 | meulaboh
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | egvekinot
# Processing Record 3 of Set 5 | zhigansk
# Processing Record 4 of Set 5 | bathsheba
# Processing Record 5 of Set 5 | coos bay
# Processing Record 6 of Set 5 | zyryanka
# Processing Record 7 of Set 5 | zhezkazgan
# Processing Record 8 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 5 | port blair
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | broager
# Processing Record 12 of Set 5 | doha
# Processing Record 13 of Set 5 | pitimbu
# Processing Record 14 of Set 5 | the valley
# Processing Record 15 of Set 5 | jucas
# Processing Record 16 of Set 5 | beatrice
# Processing Record 17 of Set 5 | othonoi
# City not found. Skipping...
# Processing Record 18 of Set 5 | san pedro de ycuamandiyu
# Processing Record 19 of Set 5 | hervey bay
# Processing Record 20 of Set 5 | dubki
# Processing Record 21 of Set 5 | aykhal
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | portland
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | iqaluit
# Processing Record 26 of Set 5 | banjar
# Processing Record 27 of Set 5 | tukums
# Processing Record 28 of Set 5 | hobyo
# Processing Record 29 of Set 5 | kiblawan
# Processing Record 30 of Set 5 | barrow
# Processing Record 31 of Set 5 | severo-kurilsk
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | mangai
# Processing Record 34 of Set 5 | varkaus
# Processing Record 35 of Set 5 | chapais
# Processing Record 36 of Set 5 | karatuzskoye
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | kuala terengganu
# Processing Record 39 of Set 5 | monrovia
# Processing Record 40 of Set 5 | dogondoutchi
# Processing Record 41 of Set 5 | maltahohe
# Processing Record 42 of Set 5 | acarau
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | souillac
# Processing Record 45 of Set 5 | tessalit
# Processing Record 46 of Set 5 | huicungo
# Processing Record 47 of Set 5 | honiara
# Processing Record 48 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 5 | montepuez
# Processing Record 50 of Set 5 | kavaratti
# Processing Record 1 of Set 6 | khatanga
# Processing Record 2 of Set 6 | kurilsk
# Processing Record 3 of Set 6 | kushmurun
# Processing Record 4 of Set 6 | szob
# Processing Record 5 of Set 6 | narsaq
# Processing Record 6 of Set 6 | thompson
# Processing Record 7 of Set 6 | coquimbo
# Processing Record 8 of Set 6 | butaritari
# Processing Record 9 of Set 6 | goderich
# Processing Record 10 of Set 6 | bonavista
# Processing Record 11 of Set 6 | price
# Processing Record 12 of Set 6 | boyolangu
# Processing Record 13 of Set 6 | saint anthony
# Processing Record 14 of Set 6 | akyab
# Processing Record 15 of Set 6 | pangnirtung
# Processing Record 16 of Set 6 | kununurra
# Processing Record 17 of Set 6 | tautira
# Processing Record 18 of Set 6 | san felipe
# Processing Record 19 of Set 6 | dudinka
# Processing Record 20 of Set 6 | ahipara
# Processing Record 21 of Set 6 | salinopolis
# Processing Record 22 of Set 6 | kologriv
# Processing Record 23 of Set 6 | mana
# Processing Record 24 of Set 6 | pavlogradka
# Processing Record 25 of Set 6 | bethel
# Processing Record 26 of Set 6 | guhagar
# Processing Record 27 of Set 6 | ouallam
# Processing Record 28 of Set 6 | tomatlan
# Processing Record 29 of Set 6 | uthal
# Processing Record 30 of Set 6 | lavrentiya
# Processing Record 31 of Set 6 | kruisfontein
# Processing Record 32 of Set 6 | teknaf
# Processing Record 33 of Set 6 | san marcos
# Processing Record 34 of Set 6 | keta
# Processing Record 35 of Set 6 | bud
# Processing Record 36 of Set 6 | chirongui
# Processing Record 37 of Set 6 | macultepec
# Processing Record 38 of Set 6 | vanimo
# Processing Record 39 of Set 6 | raudeberg
# Processing Record 40 of Set 6 | trinidad
# Processing Record 41 of Set 6 | komsomolskiy
# Processing Record 42 of Set 6 | kingisepp
# Processing Record 43 of Set 6 | kapoeta
# Processing Record 44 of Set 6 | faya
# Processing Record 45 of Set 6 | batemans bay
# Processing Record 46 of Set 6 | ibra
# Processing Record 47 of Set 6 | longyearbyen
# Processing Record 48 of Set 6 | elat
# Processing Record 49 of Set 6 | santiago del estero
# Processing Record 50 of Set 6 | oranjestad
# Processing Record 1 of Set 7 | that phanom
# Processing Record 2 of Set 7 | deming
# Processing Record 3 of Set 7 | college
# Processing Record 4 of Set 7 | vao
# Processing Record 5 of Set 7 | salina cruz
# Processing Record 6 of Set 7 | alice springs
# Processing Record 7 of Set 7 | buchanan
# Processing Record 8 of Set 7 | bykovo
# Processing Record 9 of Set 7 | kenai
# Processing Record 10 of Set 7 | umm lajj
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | kesova gora
# Processing Record 13 of Set 7 | turka
# Processing Record 14 of Set 7 | panjakent
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | oktyabrskiy
# Processing Record 17 of Set 7 | kavieng
# Processing Record 18 of Set 7 | zarand
# Processing Record 19 of Set 7 | hasaki
# Processing Record 20 of Set 7 | sechura
# Processing Record 21 of Set 7 | paka
# Processing Record 22 of Set 7 | andilamena
# Processing Record 23 of Set 7 | candolim
# Processing Record 24 of Set 7 | novo aripuana
# Processing Record 25 of Set 7 | innisfail
# Processing Record 26 of Set 7 | mayumba
# Processing Record 27 of Set 7 | nanortalik
# Processing Record 28 of Set 7 | isangel
# Processing Record 29 of Set 7 | vanavara
# Processing Record 30 of Set 7 | chuy
# Processing Record 31 of Set 7 | pullman
# Processing Record 32 of Set 7 | dalvik
# Processing Record 33 of Set 7 | totoral
# Processing Record 34 of Set 7 | itarema
# Processing Record 35 of Set 7 | port lincoln
# Processing Record 36 of Set 7 | qujing
# Processing Record 37 of Set 7 | husavik
# Processing Record 38 of Set 7 | san bernardo
# Processing Record 39 of Set 7 | sidi ali
# Processing Record 40 of Set 7 | santa cruz del sur
# Processing Record 41 of Set 7 | camacupa
# Processing Record 42 of Set 7 | katakwi
# Processing Record 43 of Set 7 | lazaro cardenas
# Processing Record 44 of Set 7 | tshela
# Processing Record 45 of Set 7 | hornepayne
# Processing Record 46 of Set 7 | koungou
# Processing Record 47 of Set 7 | bafq
# Processing Record 48 of Set 7 | moose factory
# Processing Record 49 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 7 | pontes e lacerda
# Processing Record 1 of Set 8 | straumen
# Processing Record 2 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 3 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 8 | luleburgaz
# Processing Record 5 of Set 8 | flin flon
# Processing Record 6 of Set 8 | lexington
# Processing Record 7 of Set 8 | sfantu gheorghe
# Processing Record 8 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | junagadh
# Processing Record 12 of Set 8 | nsanje
# Processing Record 13 of Set 8 | berlevag
# Processing Record 14 of Set 8 | gubkinskiy
# Processing Record 15 of Set 8 | soyo
# Processing Record 16 of Set 8 | dutse
# Processing Record 17 of Set 8 | abu samrah
# Processing Record 18 of Set 8 | cartagena
# Processing Record 19 of Set 8 | jalu
# Processing Record 20 of Set 8 | svetlyy
# Processing Record 21 of Set 8 | kutum
# Processing Record 22 of Set 8 | biu
# Processing Record 23 of Set 8 | aitape
# Processing Record 24 of Set 8 | nykobing
# City not found. Skipping...
# Processing Record 25 of Set 8 | wajir
# Processing Record 26 of Set 8 | redditch
# Processing Record 27 of Set 8 | grand haven
# Processing Record 28 of Set 8 | salinas
# Processing Record 29 of Set 8 | vakhrushev
# Processing Record 30 of Set 8 | inyonga
# Processing Record 31 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 8 | tabuk
# Processing Record 33 of Set 8 | takoradi
# Processing Record 34 of Set 8 | oktyabrskoye
# Processing Record 35 of Set 8 | sao joao da barra
# Processing Record 36 of Set 8 | sungaipenuh
# Processing Record 37 of Set 8 | maragogi
# Processing Record 38 of Set 8 | kuminskiy
# Processing Record 39 of Set 8 | olafsvik
# Processing Record 40 of Set 8 | fortuna
# Processing Record 41 of Set 8 | oranjemund
# Processing Record 42 of Set 8 | batagay-alyta
# Processing Record 43 of Set 8 | esmeraldas
# Processing Record 44 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 8 | vostok
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 48 of Set 8 | kahului
# Processing Record 49 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 50 of Set 8 | cefalu
# Processing Record 1 of Set 9 | half moon bay
# Processing Record 2 of Set 9 | den helder
# Processing Record 3 of Set 9 | lagoa
# Processing Record 4 of Set 9 | hovd
# Processing Record 5 of Set 9 | alyangula
# Processing Record 6 of Set 9 | touros
# Processing Record 7 of Set 9 | tura
# Processing Record 8 of Set 9 | asilah
# Processing Record 9 of Set 9 | cah ab
# City not found. Skipping...
# Processing Record 10 of Set 9 | luwingu
# Processing Record 11 of Set 9 | det udom
# Processing Record 12 of Set 9 | kathmandu
# Processing Record 13 of Set 9 | mareeba
# Processing Record 14 of Set 9 | lakatoro
# Processing Record 15 of Set 9 | adelaide
# Processing Record 16 of Set 9 | la palma
# Processing Record 17 of Set 9 | qaqortoq
# Processing Record 18 of Set 9 | crixas
# Processing Record 19 of Set 9 | saint-pierre
# Processing Record 20 of Set 9 | esperance
# Processing Record 21 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | saint george
# Processing Record 23 of Set 9 | romanovka
# Processing Record 24 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 9 | gao
# Processing Record 26 of Set 9 | atar
# Processing Record 27 of Set 9 | kyshtovka
# Processing Record 28 of Set 9 | svetlaya
# Processing Record 29 of Set 9 | udachnyy
# Processing Record 30 of Set 9 | anloga
# Processing Record 31 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 9 | vermilion
# Processing Record 33 of Set 9 | jacareacanga
# Processing Record 34 of Set 9 | clyde river
# Processing Record 35 of Set 9 | inuvik
# Processing Record 36 of Set 9 | ofaqim
# Processing Record 37 of Set 9 | jaciara
# Processing Record 38 of Set 9 | kot addu
# Processing Record 39 of Set 9 | asau
# Processing Record 40 of Set 9 | mandalgovi
# Processing Record 41 of Set 9 | nuqui
# Processing Record 42 of Set 9 | seymchan
# Processing Record 43 of Set 9 | manzanillo
# Processing Record 44 of Set 9 | nuuk
# Processing Record 45 of Set 9 | ocos
# Processing Record 46 of Set 9 | bilibino
# Processing Record 47 of Set 9 | kapenguria
# Processing Record 48 of Set 9 | erenhot
# Processing Record 49 of Set 9 | warri
# Processing Record 50 of Set 9 | kuytun
# Processing Record 1 of Set 10 | lunenburg
# Processing Record 2 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 10 | yumen
# Processing Record 4 of Set 10 | lasa
# Processing Record 5 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 6 of Set 10 | labuan
# Processing Record 7 of Set 10 | tromso
# Processing Record 8 of Set 10 | slave lake
# Processing Record 9 of Set 10 | north myrtle beach
# Processing Record 10 of Set 10 | san patricio
# Processing Record 11 of Set 10 | abilene
# Processing Record 12 of Set 10 | mecca
# Processing Record 13 of Set 10 | najran
# Processing Record 14 of Set 10 | simplicio mendes
# Processing Record 15 of Set 10 | tazovskiy
# Processing Record 16 of Set 10 | yar-sale
# Processing Record 17 of Set 10 | fayaoue
# Processing Record 18 of Set 10 | thinadhoo
# Processing Record 19 of Set 10 | naro
# Processing Record 20 of Set 10 | coahuayana
# Processing Record 21 of Set 10 | sorland
# Processing Record 22 of Set 10 | kerema
# Processing Record 23 of Set 10 | tuatapere
# Processing Record 24 of Set 10 | weligama
# Processing Record 25 of Set 10 | magnor
# Processing Record 26 of Set 10 | oistins
# Processing Record 27 of Set 10 | maracacume
# Processing Record 28 of Set 10 | grand-lahou
# Processing Record 29 of Set 10 | morant bay
# Processing Record 30 of Set 10 | high rock
# Processing Record 31 of Set 10 | koslan
# Processing Record 32 of Set 10 | tagusao
# Processing Record 33 of Set 10 | lodwar
# Processing Record 34 of Set 10 | vila franca do campo
# Processing Record 35 of Set 10 | mehamn
# Processing Record 36 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 37 of Set 10 | tahoua
# Processing Record 38 of Set 10 | naryan-mar
# Processing Record 39 of Set 10 | new cumnock
# Processing Record 40 of Set 10 | stjordalshalsen
# Processing Record 41 of Set 10 | otjimbingwe
# Processing Record 42 of Set 10 | baruun-urt
# Processing Record 43 of Set 10 | olimpia
# Processing Record 44 of Set 10 | fukue
# Processing Record 45 of Set 10 | kawalu
# Processing Record 46 of Set 10 | avera
# Processing Record 47 of Set 10 | iquique
# Processing Record 48 of Set 10 | ust-maya
# Processing Record 49 of Set 10 | morros
# Processing Record 50 of Set 10 | goma
# Processing Record 1 of Set 11 | bihar
# Processing Record 2 of Set 11 | nouakchott
# Processing Record 3 of Set 11 | ivanovice na hane
# Processing Record 4 of Set 11 | la fleche
# Processing Record 5 of Set 11 | fort myers beach
# Processing Record 6 of Set 11 | hanzhong
# Processing Record 7 of Set 11 | san juan
# Processing Record 8 of Set 11 | tongzi
# Processing Record 9 of Set 11 | hannibal
# Processing Record 10 of Set 11 | strezhevoy
# Processing Record 11 of Set 11 | araouane
# Processing Record 12 of Set 11 | dali
# Processing Record 13 of Set 11 | san jose el idolo
# Processing Record 14 of Set 11 | sayyan
# Processing Record 15 of Set 11 | taitung
# Processing Record 16 of Set 11 | kuyanovo
# Processing Record 17 of Set 11 | kaeo
# Processing Record 18 of Set 11 | awjilah
# Processing Record 19 of Set 11 | nabire
# Processing Record 20 of Set 11 | inhambane
# Processing Record 21 of Set 11 | port augusta
# Processing Record 22 of Set 11 | waddan
# Processing Record 23 of Set 11 | kirakira
# Processing Record 24 of Set 11 | bosaso
# Processing Record 25 of Set 11 | san quintin
# Processing Record 26 of Set 11 | burnie
# Processing Record 27 of Set 11 | ryde
# Processing Record 28 of Set 11 | berdigestyakh
# Processing Record 29 of Set 11 | seda
# Processing Record 30 of Set 11 | itapage
# Processing Record 31 of Set 11 | valparaiso
# Processing Record 32 of Set 11 | maua
# Processing Record 33 of Set 11 | rock sound
# Processing Record 34 of Set 11 | tafresh
# Processing Record 35 of Set 11 | vaitape
# Processing Record 36 of Set 11 | comodoro rivadavia
# Processing Record 37 of Set 11 | winnemucca
# Processing Record 38 of Set 11 | ahmadpur
# Processing Record 39 of Set 11 | domoni
# Processing Record 40 of Set 11 | inirida
# Processing Record 41 of Set 11 | okha
# Processing Record 42 of Set 11 | havoysund
# Processing Record 43 of Set 11 | marovoay
# Processing Record 44 of Set 11 | zhob
# Processing Record 45 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 46 of Set 11 | quatre cocos
# Processing Record 47 of Set 11 | villa carlos paz
# Processing Record 48 of Set 11 | lorengau
# Processing Record 49 of Set 11 | ukiah
# Processing Record 50 of Set 11 | danielskuil
# Processing Record 1 of Set 12 | beian
# Processing Record 2 of Set 12 | chimbote
# Processing Record 3 of Set 12 | yarmolyntsi
# Processing Record 4 of Set 12 | neyshabur
# Processing Record 5 of Set 12 | sitka
# Processing Record 6 of Set 12 | celestun
# Processing Record 7 of Set 12 | pocoes
# Processing Record 8 of Set 12 | sao sebastiao
# Processing Record 9 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 12 | yuzhno-kurilsk
# Processing Record 12 of Set 12 | chingirlau
# Processing Record 13 of Set 12 | dubai
# Processing Record 14 of Set 12 | ixtapa
# Processing Record 15 of Set 12 | goure
# Processing Record 16 of Set 12 | tarauaca
# Processing Record 17 of Set 12 | santa barbara
# Processing Record 18 of Set 12 | arroyo
# Processing Record 19 of Set 12 | vrangel
# Processing Record 20 of Set 12 | hirado
# Processing Record 21 of Set 12 | peterhead
# Processing Record 22 of Set 12 | bukachacha
# Processing Record 23 of Set 12 | maple creek
# Processing Record 24 of Set 12 | high level
# Processing Record 25 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 26 of Set 12 | vidim
# Processing Record 27 of Set 12 | nome
# Processing Record 28 of Set 12 | west sacramento
# Processing Record 29 of Set 12 | bantogon
# Processing Record 30 of Set 12 | central point
# Processing Record 31 of Set 12 | tarija
# Processing Record 32 of Set 12 | gizo
# Processing Record 33 of Set 12 | flagstaff
# Processing Record 34 of Set 12 | lingao
# Processing Record 35 of Set 12 | bassar
# Processing Record 36 of Set 12 | telimele
# Processing Record 37 of Set 12 | barbastro
# Processing Record 38 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 39 of Set 12 | adana
# Processing Record 40 of Set 12 | lowestoft
# Processing Record 41 of Set 12 | labuhan
# Processing Record 42 of Set 12 | conde
# Processing Record 43 of Set 12 | ferme-neuve
# Processing Record 44 of Set 12 | taltal
# Processing Record 45 of Set 12 | uni
# Processing Record 46 of Set 12 | yeppoon
# Processing Record 47 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 12 | beyneu
# Processing Record 49 of Set 12 | masvingo
# Processing Record 50 of Set 12 | marienburg
# Processing Record 1 of Set 13 | port hardy
# Processing Record 2 of Set 13 | amahai
# Processing Record 3 of Set 13 | bowen
# Processing Record 4 of Set 13 | sao felix do xingu
# Processing Record 5 of Set 13 | robertsport
# Processing Record 6 of Set 13 | xai-xai
# Processing Record 7 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 13 | tiznit
# Processing Record 9 of Set 13 | hirara
# Processing Record 10 of Set 13 | payo
# Processing Record 11 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 12 of Set 13 | novikovo
# Processing Record 13 of Set 13 | waw
# Processing Record 14 of Set 13 | nouadhibou
# Processing Record 15 of Set 13 | niquero
# Processing Record 16 of Set 13 | vysokopillya
# Processing Record 17 of Set 13 | benghazi
# Processing Record 18 of Set 13 | gat
# Processing Record 19 of Set 13 | svetlogorsk
# Processing Record 20 of Set 13 | boralday
# Processing Record 21 of Set 13 | yenagoa
# Processing Record 22 of Set 13 | magway
# Processing Record 23 of Set 13 | bubaque
# Processing Record 24 of Set 13 | parrita
# Processing Record 25 of Set 13 | muros
# Processing Record 26 of Set 13 | yangjiang
# Processing Record 27 of Set 13 | sioux lookout
# Processing Record 28 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 13 | matadi
# Processing Record 30 of Set 13 | igarka
# Processing Record 31 of Set 13 | bilma
# Processing Record 32 of Set 13 | cabedelo
# Processing Record 33 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 34 of Set 13 | umea
# Processing Record 35 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 13 | namibe
# Processing Record 37 of Set 13 | victor harbor
# Processing Record 38 of Set 13 | mahanje
# Processing Record 39 of Set 13 | nemuro
# Processing Record 40 of Set 13 | praya
# Processing Record 41 of Set 13 | dingzhou
# Processing Record 42 of Set 13 | boca do acre
# Processing Record 43 of Set 13 | lentekhi
# Processing Record 44 of Set 13 | laguna
# Processing Record 45 of Set 13 | tall kayf
# Processing Record 46 of Set 13 | carbonia
# Processing Record 47 of Set 13 | kampot
# Processing Record 48 of Set 13 | rawson
# Processing Record 49 of Set 13 | sarapulka
# Processing Record 50 of Set 13 | miri
# Processing Record 1 of Set 14 | belyy yar
# Processing Record 2 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 14 | caxias
# Processing Record 4 of Set 14 | mezen
# Processing Record 5 of Set 14 | altay
# Processing Record 6 of Set 14 | metu
# Processing Record 7 of Set 14 | camalu
# Processing Record 8 of Set 14 | rustenburg
# Processing Record 9 of Set 14 | te anau
# Processing Record 10 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 14 | aripuana
# Processing Record 12 of Set 14 | pringsewu
# Processing Record 13 of Set 14 | tirumullaivasal
# Processing Record 14 of Set 14 | centralia
# Processing Record 15 of Set 14 | atherton
# Processing Record 16 of Set 14 | guerrero negro
# Processing Record 17 of Set 14 | serov
# Processing Record 18 of Set 14 | san pedro
# Processing Record 19 of Set 14 | rockland
# Processing Record 20 of Set 14 | ivdel
# Processing Record 21 of Set 14 | chaozhou
# Processing Record 22 of Set 14 | raton
# Processing Record 23 of Set 14 | praia da vitoria
# Processing Record 24 of Set 14 | zaidpur
# Processing Record 25 of Set 14 | macau
# Processing Record 26 of Set 14 | melfi
# Processing Record 27 of Set 14 | changchun
# Processing Record 28 of Set 14 | kayanga
# Processing Record 29 of Set 14 | jutai
# Processing Record 30 of Set 14 | sombrio
# Processing Record 31 of Set 14 | saint-augustin
# Processing Record 32 of Set 14 | harrison
# Processing Record 33 of Set 14 | west wendover
# Processing Record 34 of Set 14 | chandbali
# Processing Record 35 of Set 14 | qasigiannguit
# Processing Record 36 of Set 14 | alghero
# Processing Record 37 of Set 14 | necochea
# Processing Record 38 of Set 14 | walvis bay
# Processing Record 39 of Set 14 | phan thiet
# Processing Record 40 of Set 14 | loudeac
# Processing Record 41 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 14 | minab
# Processing Record 43 of Set 14 | barra
# Processing Record 44 of Set 14 | barabinsk
# Processing Record 45 of Set 14 | uk
# City not found. Skipping...
# Processing Record 46 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 47 of Set 14 | shakawe
# Processing Record 48 of Set 14 | saint-joseph
# Processing Record 49 of Set 14 | orocue
# Processing Record 50 of Set 14 | urengoy
# Processing Record 1 of Set 15 | fernie
# Processing Record 2 of Set 15 | chipinge
# Processing Record 3 of Set 15 | iguai
# Processing Record 4 of Set 15 | sinnamary
# Processing Record 5 of Set 15 | north platte
# Processing Record 6 of Set 15 | aswan
# Processing Record 7 of Set 15 | grand gaube
# Processing Record 8 of Set 15 | sur
# Processing Record 9 of Set 15 | moree
# Processing Record 10 of Set 15 | coolum beach
# Processing Record 11 of Set 15 | itoman
# Processing Record 12 of Set 15 | mount isa
# Processing Record 13 of Set 15 | arlit
# Processing Record 14 of Set 15 | rosetta
# Processing Record 15 of Set 15 | nyurba
# Processing Record 16 of Set 15 | vilyuysk
# Processing Record 17 of Set 15 | khristoforovo
# City not found. Skipping...
# Processing Record 18 of Set 15 | kharp
# Processing Record 19 of Set 15 | mattru
# Processing Record 20 of Set 15 | ypsonas
# Processing Record 21 of Set 15 | la ronge
# Processing Record 22 of Set 15 | tshikapa
# Processing Record 23 of Set 15 | whyalla
# Processing Record 24 of Set 15 | konstantinovo
# Processing Record 25 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 26 of Set 15 | pasni
# Processing Record 27 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 28 of Set 15 | rio gallegos
# Processing Record 29 of Set 15 | kanashevo
# Processing Record 30 of Set 15 | gornyak
# Processing Record 31 of Set 15 | ust-omchug
# Processing Record 32 of Set 15 | sumenep
# Processing Record 33 of Set 15 | vestmannaeyjar
# Processing Record 34 of Set 15 | plouzane
# Processing Record 35 of Set 15 | bac giang
# Processing Record 36 of Set 15 | galesong
# Processing Record 37 of Set 15 | kannur
# Processing Record 38 of Set 15 | alta floresta
# Processing Record 39 of Set 15 | whitehorse
# Processing Record 40 of Set 15 | pinawa
# Processing Record 41 of Set 15 | yeniseysk
# Processing Record 42 of Set 15 | jipijapa
# Processing Record 43 of Set 15 | amga
# Processing Record 44 of Set 15 | rio grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 679      Bac Giang  21.2667  106.2000    292.19        81          10
# 680       Galesong  -5.3166  119.3661    297.16        76         100
# 681         Kannur  11.8675   75.3576    297.57        90          83
# 682  Alta Floresta  -9.8756  -56.0861    301.16        62          99
# 683     Whitehorse  60.7161 -135.0538    271.49        93          75
# 684         Pinawa  50.1489  -95.8811    281.63        48           5
# 685      Yeniseysk  58.4497   92.1703    276.11        78         100
# 686       Jipijapa  -1.3333  -80.5833    296.87        72          99
# 687           Amga  60.8953  131.9608    272.14        99         100
# 688     Rio Grande -32.0350  -52.0986    301.21        65           0
#
#      Wind Speed Country                 Date Weather description
# 679        1.26      VN  2021-10-25 21:29:49           clear sky
# 680        1.82      ID  2021-10-25 21:29:49     overcast clouds
# 681        1.73      IN  2021-10-25 21:29:50       broken clouds
# 682        1.61      BR  2021-10-25 21:29:50     overcast clouds
# 683        2.06      CA  2021-10-25 21:29:51       broken clouds
# 684        4.51      CA  2021-10-25 21:29:51           clear sky
# 685        6.28      RU  2021-10-25 21:29:52     overcast clouds
# 686        1.94      EC  2021-10-25 21:29:52     overcast clouds
# 687        0.93      RU  2021-10-25 21:29:52          light snow
# 688        4.76      BR  2021-10-25 21:29:53           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_weather = requests.get(city_url).json()
city_country = city_weather["sys"]["country"]
weather_description= city_weather["weather"][0]["description"]
weather_description

# %%
city_weather

# %%
# Loop through all the cities in the list.
temp_cities=cities[0:10]


for i, city in enumerate(temp_cities):

    # Group cities in sets of 50 for logging purposes.
    
    set_count = 1
    record_count = 1
    # Create endpoint URL with each city.
    url=f"http://api.openweathermap.org/data/2.5/weather?q={city.title()}&appid={weather_api_key}"
    city_url = url
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description= city_weather["weather"][0]["description"]
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather description": weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)

# %%
print(temp_cities)
